# %%
import pathlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

import cdflib

fname = ('./wi_h2_mfi_20220917_v03.cdf')

def test_context(data):
    with cdflib.CDF(fname) as cdf:
        cdf.cdf_info()
        return cdflib.CDF(fname)[data]

# %%
EPOCH_eti = [['EPOCH']]
EPOCH = test_context(0)
Time_PB5_eti = test_context(24)
Time_PB5 = test_context(1)
BF1_eti = [['BF1']]
BF1 = test_context(2)
BGSM_eti = test_context(27)
BGSM = test_context(3)
BGSE_eti = test_context(28)
BGSE = test_context(4)
RANGE_eti = [['RANGE']]
RANGE = test_context(5)
SPS_MODE_eti = [['SPC_MODE']]
SPS_MODE = test_context(6)
MAG_MODE_eti = [['MAG_MODE']]
MAG_MODE = test_context(7)
EPOCH_1_eti = [['EPOCH_1']]
EPOCH_1 = test_context(8)
Time_1_PB5_eti = test_context(26)
Time_1_PB5 = test_context(9)
NUM_1_PTS_O_eti = [['NUM_1_PTS_O']]
NUM_1_PTS_O = test_context(10)
ZERO1_O_eti = [['ZERO1_O']]
ZERO1_O = test_context(11)
SENS1_O_eti = [['SENS1_O']]
SENS1_O = test_context(12)
AMPL1_O_eti = [['AMPL1_O']]
AMPL1_O = test_context(13)
ORTH1_O_eti = [['ORTH1_O']]
ORTH1_O = test_context(14)
PAYLD1_O_eti = [['PAYLD1_O']]
PAYLD1_O = test_context(15)
FLAG1_O_eti = [['FLAG1_O']]
FLAG1_O = test_context(16)
NUM_1_PTS_1_eti = [['NUM_1_PTS_1']]
NUM_1_PTS_1 = test_context(17)
ZERO1_I_eti = [['ZERO1_I']]
ZERO1_I = test_context(18)
SENS1_I_eti = [['SENS1_I']]
SENS1_I = test_context(19)
AMPL1_I_eti = [['AMPL1_I']]
AMPL1_I = test_context(20)
ORTH1_I_eti = [['ORTH1_I']]
ORTH1_I = test_context(21)
PAYLD1_I_eti = [['PAYLD1_I']]
PAYLD1_I = test_context(22)
FLAG1_I_eti = [['FLAG1_I']]
FLAG1_I = test_context(23)

# %%
data = np.c_[EPOCH,BF1,BGSM,BGSE]
print(data.shape)
# Out:
# (919244, 8)

# %%
data=pd.DataFrame(data)

# %%
data.columns = ['EPOCH',
             'BF1',
             'BGSM(X)',
             'BGSM(Y)',
             'BGSM(Z)',
             'BGSE(X)',
             'BGSE(Y)',
             'BGSE(Z)']
data.head()
# Out:
#           EPOCH       BF1   BGSM(X)   BGSM(Y)   BGSM(Z)   BGSE(X)   BGSE(Y)  \
# 0  6.383059e+13  5.963605  5.610643  0.694208  1.898247  5.610641  0.207963
# 1  6.383059e+13  5.950454  5.593054  0.643184  1.926648  5.593052  0.151535
# 2  6.383059e+13  5.936640  5.572175  0.613837  1.953912  5.572173  0.116402
# 3  6.383059e+13  5.921311  5.554674  0.628270  1.952640  5.554672  0.130706
# 4  6.383059e+13  5.927860  5.562888  0.696311  1.925864  5.562886  0.203233
#
#     BGSE(Z)
# 0  2.010482
# 1  2.025516
# 2  2.044759
# 3  2.047062
# 4  2.037772

# %%
data.to_csv("wind.csv")

# %%
plt.figure(figsize=(10,5))
plt.plot(EPOCH, BF1)
plt.title('Magnetic Field Magnitude')
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Magnetic Field Magnitude (nT)')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Magnetic Field Vector in GSM Cartesian (nT)')
plt.title('Magnetic Field Vector in GSM Cartesian')
plt.plot(EPOCH, BGSM[:,0], label = 'BGSM(X)')
plt.plot(EPOCH, BGSM[:,1], label = 'BGSM(Y)')
plt.plot(EPOCH, BGSM[:,2], label = 'BGSM(Z)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Magnetic Field Vector in GSE Cartesian (nT)')
plt.title('Magnetic Field Vector in GSE Cartesian')
plt.plot(EPOCH, BGSE[:,0], label = 'BGSE(X)')
plt.plot(EPOCH, BGSE[:,1], label = 'BGSE(Y)')
plt.plot(EPOCH, BGSE[:,2], label = 'BGSE(Z)')
plt.legend()
plt.show()

# %%
fname2 = ('./dscovr_h0_mag_20220917_v01.cdf')

def test_context(data):
    with cdflib.CDF(fname2) as cdf:
        cdf.cdf_info()
        return cdflib.CDF(fname2)[data]

# %%
print(test_context(3))
# Out:
# [6.1663065 6.155649  6.101967  ... 9.456322  9.618543  9.631919 ]

# %%
EPOCH1_eti = [['EPOCH']]
EPOCH1 = test_context(0)
Time_PB5_eti = test_context(13)
Time_PB5 = test_context(1)
B1F1_eti = [['BF1']] # BF1
B1F1 = test_context(3)
B1F1_SDF_1_eti = [['BF1_SDF_1']] # Desviación Estandar de BF1
B1F1_SDF_1 = test_context(4)
B1GSE_eti = [['BGSE']] # BGSE
B1GSE = test_context(5)
B1_SDGSE_eti = [['B1_SDGSE']] #Desviación Estandar de BGSE
B1_SDGSE = test_context(6)
B1RTN_eti = [['B1_RTN']] #B1_RTN
B1RTN = test_context(7)
B1_SDRTN_eti = [['B1_SDRTN']] #B1_RTN
B1_SDRTN = test_context(8)

# %%
data_2 = np.c_[EPOCH1,B1F1,B1GSE,B1RTN]

# %%
data_2=pd.DataFrame(data_2)
data_2.columns = ['EPOCH1',
             'B1F1',
             'B1GSE(X)',
             'B1GSE(Y)',
             'B1GSE(Z)',
             'B1RTN(X)',
             'B1RTN(Y)',
             'B1RTN(Z)']
data_2.head()
# Out:
#          EPOCH1      B1F1  B1GSE(X)  B1GSE(Y)  B1GSE(Z)  B1RTN(X)  B1RTN(Y)  \
# 0  6.383059e+13  6.166306  3.366875 -4.489628 -2.554131 -3.375257  4.438591
# 1  6.383059e+13  6.155649  3.158954 -4.531584 -2.711795 -3.167476  4.478099
# 2  6.383059e+13  6.101967  2.891628 -4.516340 -2.907708 -2.900215  4.459837
# 3  6.383059e+13  6.116212  2.978833 -4.581107 -2.745199 -2.987450  4.527315
# 4  6.383059e+13  6.118779  3.044112 -4.594254 -2.655434 -3.052710  4.541934
#
#    B1RTN(Z)
# 0 -2.631111
# 1 -2.789589
# 2 -2.985332
# 3 -2.823946
# 4 -2.734395

# %%
data_2.to_csv("dscovr.csv")

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.plot(EPOCH1, B1F1)
plt.title('Magnetic Field Magnitude')
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Magnetic Field Magnitude (nT)')
plt.subplot(122)
plt.plot(EPOCH1[0:5000], BF1[0:5000])
plt.title('Magnetic Field Magnitude')
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Magnetic Field Magnitude (nT)')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Magnetic Field Vector in GSM Cartesian (nT)')
plt.title('Magnetic Field Vector in GSM Cartesian')
plt.plot(EPOCH1, B1GSE[:,0], label = 'B1GSE(X)')
plt.plot(EPOCH1, B1GSE[:,1], label = 'B1GSE(Y)')
plt.plot(EPOCH1, B1GSE[:,2], label = 'B1GSE(Z)')
plt.legend()
plt.subplot(122)
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Magnetic Field Vector in GSE Cartesian (nT)')
plt.title('Magnetic Field Vector in GSE Cartesian')
plt.plot(EPOCH1[0:5000], B1GSE[0:5000,0], label = 'B1GSE(X)')
plt.plot(EPOCH1[0:5000], B1GSE[0:5000,1], label = 'B1GSE(Y)')
plt.plot(EPOCH1[0:5000], B1GSE[0:5000,2], label = 'B1GSE(Z)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Magnetic Field Vector in RTN Cartesian (nT)')
plt.title('Magnetic Field Vector in RTN Cartesian')
plt.plot(EPOCH1, B1RTN[:,0], label = 'B1RTN(X)')
plt.plot(EPOCH1, B1RTN[:,1], label = 'B1RTN(Y)')
plt.plot(EPOCH1, B1RTN[:,2], label = 'B1RTN(Z)')
plt.legend()
plt.subplot(122)
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Magnetic Field Vector in RTN Cartesian (nT)')
plt.title('Magnetic Field Vector in RTN Cartesian')
plt.plot(EPOCH1[0:5000], B1RTN[0:5000,0], label = 'B1RTN(X)')
plt.plot(EPOCH1[0:5000], B1RTN[0:5000,1], label = 'B1RTN(Y)')
plt.plot(EPOCH1[0:5000], B1RTN[0:5000,2], label = 'B1RTN(Z)')
plt.legend()
plt.show()

# %%
fname3 = ('./wi_h1_swe_20220825_v01.cdf')

def test_context(data):
    with cdflib.CDF(fname3) as cdf:
        cdf.cdf_info()
        return cdflib.CDF(fname3)[data]

EPOCH2 = test_context(1)
Vx = test_context(6)
Vy = test_context(8)
Vz = test_context(10)
W = test_context(12)
Np = test_context(23)

# %%
plt.figure(figsize=(10,5))
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Wind Ion Velocity (K/s)')
plt.title('Magnetic Field Vector in RTN Cartesian')
plt.plot(EPOCH2, Vx, label = 'Vx')
plt.plot(EPOCH2, Vy, label = 'Vy')
plt.plot(EPOCH2, Vz, label = 'Vz')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(EPOCH2, W)
plt.title('Scalar Proton Thermal')
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Scalar Proton Thermal [isotropic] (K/m)')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(EPOCH2, Np)
plt.title('Proton Number Density')
plt.xlabel('Milliseconds (ms)')
plt.ylabel('Proton Number Density (cm^-3)')
plt.show()
